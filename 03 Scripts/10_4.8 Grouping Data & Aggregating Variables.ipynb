# %% [markdown]
# ### 01. Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 02. Importing dataframe

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\veren\Python Data\26-10-2021 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_dnv.pkl')

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3   1813452      764    prior             3          4                 17
# 4   1701441      777    prior            16          1                  7
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (30356128, 19)

# %%
# Creating a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.groupby('product_name')

# %%
# Performing a single aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.687405
# 2                18.376471
# 3                18.006568
# 4                18.615042
# 5                16.076584
# 6                17.794122
# 7                18.145902
# 8                16.088431
# 9                16.564123
# 10               19.554859
# 11               16.602652
# 12               15.491845
# 13               17.705803
# 14               17.815154
# 15               17.290386
# 16               18.916198
# 17               17.085095
# 18               20.758164
# 19               17.829739
# 20               17.349545
# 21               26.292422

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     16.687405
# 2     18.376471
# 3     18.006568
# 4     18.615042
# 5     16.076584
# 6     17.794122
# 7     18.145902
# 8     16.088431
# 9     16.564123
# 10    19.554859
# 11    16.602652
# 12    15.491845
# 13    17.705803
# 14    17.815154
# 15    17.290386
# 16    18.916198
# 17    17.085095
# 18    20.758164
# 19    17.829739
# 20    17.349545
# 21    26.292422
# Name: order_number, dtype: float64

# %%
# Performing multiple aggregations
df.groupby('department_id').agg({'order_number':['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                16.687405   2  99
# 2                18.376471   2  96
# 3                18.006568   2  99
# 4                18.615042   2  99
# 5                16.076584   2  99
# 6                17.794122   2  99
# 7                18.145902   2  99
# 8                16.088431   2  98
# 9                16.564123   2  99
# 10               19.554859   2  99
# 11               16.602652   2  99
# 12               15.491845   2  99
# 13               17.705803   2  99
# 14               17.815154   2  99
# 15               17.290386   2  99
# 16               18.916198   2  99
# 17               17.085095   2  99
# 18               20.758164   2  99
# 19               17.829739   2  99
# 20               17.349545   2  99
# 21               26.292422   2  98

# %% [markdown]
# ### 03. Creating a loyalty flag using loc

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
ords_prods_merge.shape
# Out:
# (30356128, 20)

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Pulling the values from the "loyalty flag" column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15095208
# Loyal customer      10104845
# New customer         5156075
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             3
# 4       777  Regular customer            16
# 5       825      New customer             3
# 6       910  Regular customer            12
# 7      1052  Regular customer            10
# 8      1052  Regular customer            15
# 9      1480    Loyal customer            36
# 10     1480    Loyal customer            38
# 11     1480    Loyal customer            39
# 12     1494  Regular customer             6
# 13     1494  Regular customer             7
# 14     1494  Regular customer             9
# 15     1540  Regular customer             4
# 16     1540  Regular customer             5
# 17     1540  Regular customer             6
# 18     1540  Regular customer             7
# 19     1540  Regular customer             8
# ...

# %%
path = r'C:\Users\veren\Python Data\26-10-2021 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\veren\\Python Data\\26-10-2021 Instacart Basket Analysis'

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_GDAV.pkl'))
